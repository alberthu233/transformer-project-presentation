# %%
from datasets import load_dataset
import random
import time
import pickle

random.seed(0)

def sample_from_dataset(dataset, num):
  return dataset.shuffle()[:num]

# %%
import os
import pandas as pd
import tqdm.notebook as tqdm

from datasets import load_dataset
import random

from transformers import AutoTokenizer, GemmaForCausalLM, BitsAndBytesConfig, AutoModelForCausalLM
import torch

os.chdir('/workspace/ligo_general/prompt')

# %%
import pathlib
import textwrap
import google.generativeai as genai

# %%
genai.configure(api_key=API_KEY)
model = genai.GenerativeModel('gemini-1.0-pro')

# %%
random.seed(0)

def sample_from_dataset(dataset, num):
  return dataset.shuffle()[:num]

cnn_dm = load_dataset('cnn_dailymail', '3.0.0')
samsum = load_dataset('samsum')
arxiv = load_dataset('scientific_papers', 'arxiv')
pubmed = load_dataset('scientific_papers', 'pubmed')
billsum = load_dataset('billsum')
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1429: FutureWarning: The repository for scientific_papers contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/scientific_papers
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
n_train = 10000
n_valid = 800
n_test = 800

cnn_train = sample_from_dataset(cnn_dm['train'], n_train)
sam_train = sample_from_dataset(samsum['train'], n_train)
arx_train = sample_from_dataset(arxiv['train'], n_train // 2)
pub_train = sample_from_dataset(pubmed['train'], n_train // 2)
bill_sample = sample_from_dataset(billsum['train'], n_train + n_valid)
balanced_train_txt = cnn_train['article'] + sam_train['dialogue'] + arx_train['article'] + pub_train['article'] + bill_sample['text'][:n_train]
balanced_train_sum = cnn_train['highlights'] + sam_train['dialogue'] + arx_train['abstract'] + pub_train['abstract'] + bill_sample['summary'][:n_train]
text = balanced_train_txt + balanced_train_sum
# sample 2000 from text
text = random.sample(text, 2000)

# %%
aspects_areas = [
    {
        "name": "Tone Adjustment",
        "description": "Modify the tone of the given text to convey a specific emotion or attitude, such as formal, friendly, assertive, or empathetic, and etc. Ensure the adjusted tone is consistent throughout the entire text and aligns with the intended message."
    },
    {
        "name": "Style Transformation",
        "description": "Transform the writing style of the given text to match a target style, such as academic, journalistic, or creative, and etc. Maintain the core content and meaning of the text while adapting its language, sentence structure, and overall presentation to the desired style."
    },
    {
        "name": "Satirical or Parodic Twist",
        "description": "Inject satire or parody into the text, rewriting it in a way that humorously critiques or lampoons the original content, characters, or themes. This approach requires a delicate balance of humor, critique, and creativity to entertain while possibly offering commentary."
    },
    {
        "name": "Age-Specific Adaptation",
        "description": "Tailor the text to a specific age group, adjusting the language, content, and presentation to be age-appropriate and engaging for that demographic. This could involve simplifying concepts for children, incorporating youthful slang for teenagers, or addressing topics relevant to seniors."
    },
    {
        "name": "Paraphrasing",
        "description": "Paraphrase the given text, maintaining its original meaning but using different words and sentence structures. Ensure the paraphrased text is clear, concise, and easier to understand for a wide audience."
    },
    {
        "name": "Summarization",
        "description": "Summarize the given text, capturing the main points and key information while omitting unnecessary details. The summary should be concise yet comprehensive, allowing readers to quickly grasp the essence of the original text."
    },
    {
        "name": "Text Simplification",
        "description": "Simplify the given text by reducing its complexity, using simpler vocabulary, shorter sentences, and clearer explanations, and etc. The simplified text should be easily understandable by a broader audience, including non-native speakers and readers with varying levels of literacy."
    },
    {
        "name": "Content Expansion",
        "description": "Expand the given text by adding relevant details, examples, explanations, or background information, and etc. The expanded content should provide a more comprehensive and in-depth understanding of the topic while maintaining coherence and readability."
    },
    {
        "name": "Perspective Shift",
        "description": "Rewrite the given text from a different perspective or point of view, such as from a specific character, stakeholder, or demographic, and etc. The rewritten text should accurately reflect the chosen perspective while preserving the overall message and context."
    },
    {
        "name": "Dialogue Generation",
        "description": "Generate realistic and engaging dialogue based on a given context, scenario, or set of characters, and etc. The generated dialogue should be natural, coherent, and consistent with the personalities and relationships of the involved parties."
    },
    {
        "name": "Text Normalization",
        "description": "Normalize the given text by converting abbreviations, slang, or informal language into standard, formal language, and etc. The normalized text should maintain the original meaning while adhering to proper grammar, spelling, and punctuation conventions."
    },
    {
        "name": "Localization and Personalization",
        "description": "Adapt the given text to specific locales, cultures, or audience demographics. This may involve modifying vocabulary, examples, references, or tone, and etc to better resonate with the target audience and ensure cultural relevance and sensitivity."
    },
    {
        "name": "Genre Conversion",
        "description": "Transform the given text to fit a specific literary or content genre, such as converting a news article into a fairy tale, a scientific report into a poem, or a business memo into a short story, and etc. This requires not only a change in style and tone but also a creative reimagining of the content to align with genre conventions."
    },
    {
        "name": "Historical Period Adaptation",
        "description": "Rewrite the text as if it were written in a different historical period, using the language, idioms, and cultural references appropriate to that time, and etc. This could involve converting modern prose into Shakespearean English, translating contemporary dialogue into the vernacular of the 1920s, or presenting a current event in the style of a medieval chronicle."
    },
    {
        "name": "Technical Jargon Incorporation or Removal",
        "description": "Either simplify technical text by removing jargon and complex language to make it accessible to a general audience or, conversely, increase the technical level of a general text by incorporating specific jargon and concepts from fields like medicine, law, or engineering, and etc."
    },
    {
        "name": "Narrative Voice Alteration",
        "description": "Change the narrative voice or point of view of the text. This could involve shifting from first-person to third-person narration, changing from passive to active voice, or rewriting a narrative to be told from the perspective of a different character or object within the story."
    },
    {
        "name": "Emotional Tone Infusion",
        "description": "Infuse the text with a specific emotional tone or mood, such as joy, sadness, suspense, or nostalgia, without altering the fundamental message. This requires subtle changes in word choice, sentence rhythm, and imagery to evoke the desired emotional response in the reader."
    },
    {
        "name": "Cross-Cultural Adaptation",
        "description": "Adapt the text to resonate with readers from a different cultural background, which involves more than just translation. It includes adjusting cultural references, metaphors, and societal norms to be more inclusive or relevant to the new audience while maintaining the essence and purpose of the original text."
    },
    {
        "name": "Interactive Content Creation",
        "description": "Transform the text into an interactive format, such as a choose-your-own-adventure story, an interactive tutorial, or a role-playing game script. This involves not just rewriting but reimagining the content as a branching narrative or dialogue with multiple paths and outcomes based on reader or user choices."
    },
    {
        "name": "Multimedia Adaptation",
        "description": "Convert the text into a script or storyboard for multimedia use, such as a video, podcast, or comic strip. This involves visualizing how the text can be represented using different media and creating detailed instructions or scripts that align with the original message but leverage the strengths of the chosen format."
    },
    {
        "name": "Sensory Detail Enhancement",
        "description": "Enhance the text by adding rich sensory details to make descriptions more vivid and engaging. This could involve describing scenes, emotions, or actions in a way that appeals to the senses (sight, sound, touch, taste, and smell), enriching the reader's experience and immersion."
    },
    {
        "name": "Ethical or Philosophical Examination",
        "description": "Rewrite the text to highlight or explore ethical dilemmas, philosophical questions, or moral lessons. This could involve adding scenarios, dialogues, or reflections that prompt readers to consider deeper meanings or the moral implications of the content."
    },
    {
        "name": "Mythological Retelling",
        "description": "Transform the text by weaving in mythological elements or themes, retelling the story or information through the lens of gods, mythical creatures, or ancient folklore. This could involve integrating characters from mythology or reimagining events as epic tales."
    },
    {
        "name": "Science Fiction or Fantasy Conversion",
        "description": "Adapt the text into a science fiction or fantasy setting, incorporating elements like advanced technology, alien societies, magical realms, or dystopian futures. This encourages creative reimagining of the original content in a way that explores alternate realities or universes."
    },
    {
        "name": "Educational Curriculum Development",
        "description": "Transform the text into an educational module or curriculum, complete with objectives, lessons, activities, and assessments. This adaptation should make the content suitable for learning environments, tailoring the information to fit educational goals and student engagement strategies."
    },
    {
        "name": "Health and Wellness Emphasis",
        "description": "Edit the text to focus on health and wellness, whether by incorporating advice on physical health, mental well-being, or lifestyle improvements. The rewritten content should offer valuable insights or tips that promote a healthier, more balanced lifestyle."
    },
    {
        "name": "Cultural Festival or Holiday Incorporation",
        "description": "Integrate elements of a specific cultural festival, holiday, or celebration into the text, adapting the content to reflect the traditions, rituals, and significance of the event. This could involve describing celebrations, historical backgrounds, or cultural practices related to the occasion."
    }
]

# %%
def generate_rewrite_prompts(aspect_area, original_texts, count):
    prompts = []
    aspect_area = random.choice(aspect_area)
    for original_text in random.sample(original_texts, count):
        aspect_name = aspect_area["name"]
        aspect_description = aspect_area["description"]

        # Generate a prompt that includes a brief of the original text
        prompt = f"Please craft a unique sentence that instruct a test taker to rewrite this text '{original_text}'(do not include this in the instruction) based on this rewriting task '{aspect_name}', create a unique, clear, and specific instruction. This instruction should be tailored to enhance or transform the provided text snippet in a way that aligns with the task's objective. It should not only fit within a 30-word limit. Come up with the tasks, genre, style, aspect, or example and etc directly when you ask the test taker, and ensure the sentence is clear and engaging without requiring further instruction or the inclusion of brackets or placeholders. Create a standalone sentence that embodies all these criteria, making sure it's free from any special characters or symbols. Thanks!"

        response = model.generate_content(
            prompt,
            generation_config=genai.types.GenerationConfig(
                temperature=0.9)
        )

        # Simulate calling an API with the prompt (for illustration purposes)
        # Replace this part with your actual API call
        # response = "Imagine the API response generates a creative and specific rewrite prompt based on the input."

        generated_prompt = response.candidates[0].content.parts[0].text
        print(f"{generated_prompt}")
        # Check for special characters
        special_chars = ['[', ']', '<', '>', '{', '}']
        if any(char in generated_prompt for char in special_chars):
            print("Special characters found in the generated prompt. Skipping...")
            continue 

        prompts.append(generated_prompt)
        
        time.sleep(1)  # Delay to avoid rate limits or for simulation

    return prompts

# Prepare DataFrame for storing original texts and rewrite prompts
df = pd.DataFrame(columns=['Original Text', 'Rewrite Prompt'])

# Example usage with a single text and aspect area
original_texts = random.sample(text, 2000)  # Assuming 'text' is your list of original texts
#aspect_area = random.choice(aspects_areas)  # Assuming 'guiding_dictionary' is accessible and contains your rewrite aspects

for original_text in original_texts:
    try:
        prompts = generate_rewrite_prompts(aspects_areas, original_text, 1)
        for prompt in prompts:
            df = df.append({'Original Text': original_text, 'Rewrite Prompt': prompt}, ignore_index=True)
        time.sleep(1)
    except Exception as e:
        print(f"Reached the API limit, pausing for 5 minutes. Error: {e}")
        time.sleep(300)
        continue
# Out:
# Compose a captivating mythological retelling by infusing a fresh perspective, imaginative elements, and a distinctive writing style into your rewrite of the provided text.
# /tmp/ipykernel_390250/4278582576.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Original Text': original_text, 'Rewrite Prompt': prompt}, ignore_index=True)
# Enhance the sensory experience of this text by infusing vivid descriptions that ignite the reader's senses, evoking specific sights, sounds, smells, tastes, and textures.
# /tmp/ipykernel_390250/4278582576.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Original Text': original_text, 'Rewrite Prompt': prompt}, ignore_index=True)
# Expand the substance of the text by adding at least 25% more words, incorporating new examples, varying sentence structure, and diversifying vocabulary to enhance clarity and engagement.
# /tmp/ipykernel_390250/4278582576.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Original Text': original_text, 'Rewrite Prompt': prompt}, ignore_index=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 47
#      45     for prompt in prompts:
#      46         df = df.append({'Original Text': original_text, 'Rewrite Prompt': prompt}, ignore_index=True)
# ---> 47     time.sleep(1)
#      48 except Exception as e:
#      49     print(f"Reached the API limit, pausing for 5 minutes. Error: {e}")
#
# KeyboardInterrupt:

# %%
original_texts = random.sample(text, 2000)

# %%
original_texts[10][:500]
# Out:
# "SECTION 1. SHORT TITLE.\n\n    This Act may be cited as the ``Securing Our Nation's Application \nPrivacy Act of 2014'' or the ``SNAP Act of 2014''.\n\nSEC. 2. ACCESS BY MOBILE APPLICATIONS TO CERTAIN DEVICE CONTENT AND \n              FUNCTIONS.\n\n    (a) In General.--Not later than 1 year after the date of the \nenactment of this Act, the Federal Trade Commission shall promulgate \nregulations in accordance with section 553 of title 5, United States \nCode, that require--\n            (1) any person who "

# %%
rewrite_prompts
# Out:
# [response:
#  GenerateContentResponse(
#      done=True,
#      iterator=None,
#      result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': 'Adapt the excerpt to make it more inclusive and appropriate for a diverse audience. Consider cultural nuances, avoiding stereotypes, and ensuring that the text respects the identities and experiences of different groups.'}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}], 'prompt_feedback': {'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'block_reason': 0}}),
#  ),
#  response:
#  GenerateContentResponse(
#      done=True,
#      iterator=None,
#      result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': 'Localize and personalize the text to resonate with Paula, a Spanish-speaking professional in Mexico City who is preparing for a presentation.'}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}], 'prompt_feedback': {'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'block_reason': 0}}),
#  ),
#  response:
#  GenerateContentResponse(
#      done=True,
#      iterator=None,
#      result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': 'Reimagine the text as a tale woven by ancient bards. Let mythical beings grace the narrative, their actions echoing the grandeur of Olympus.'}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}], 'prompt_feedback': {'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'block_reason': 0}}),
#  ),
#  response:
#  GenerateContentResponse(
#      done=True,
#      iterator=None,
#      result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': 'Reimagine the text as a captivating mythological tale, where gods and mythical beings weave their powers and influence, transforming the narrative into an epic tapestry.'}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}], 'prompt_feedback': {'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'block_reason': 0}}),
#  ),
#  response:
#  GenerateContentResponse(
#      done=True,
#      iterator=None,
#      result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': 'Transform the given snippet into an academic style, maintaining the core content, and refining the language, sentence structure, and overall presentation to reflect academic writing standards.'}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}], 'prompt_feedback': {'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'block_reason': 0}}),
#  ),
#  response:
#  GenerateContentResponse(
#      done=True,
#      iterator=None,
#      result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': 'Rephrase the following text in an academic style: "we present here a new method using interferometri..."'}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}], 'prompt_feedback': {'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'block_reason': 0}}),
#  ),
#  response:
#  GenerateContentResponse(
#      done=True,
#      iterator=None,
#      result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': "Adjust the tone of the following text to convey a friendly and approachable attitude: 'Ruth: HI girl, how long are you staying at your pa...'"}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}], 'prompt_feedback': {'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'block_reason': 0}}),
#  ),
#  response:
#  GenerateContentResponse(
#      done=True,
#      iterator=None,
#      result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': 'Rephrase the text to sound more friendly and approachable while maintaining its core message.'}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}], 'prompt_feedback': {'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'block_reason': 0}}),
#  ),
#  response:
#  GenerateContentResponse(
#      done=True,
#      iterator=None,
#      result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': 'Transform this legal text into a captivating tale that unfolds in a realm of intrigue and adventure. Let your imagination soar as you craft a narrative that captivates readers with its unique characters, settings, and plot.'}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}], 'prompt_feedback': {'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'block_reason': 0}}),
#  ),
#  response:
#  GenerateContentResponse(
#      done=True,
#      iterator=None,
#      result=glm.GenerateContentResponse({'candidates': [{'content': {'parts': [{'text': "Reimagine the text excerpt as a poignant monologue from a character named Shirley, exploring her longing and concern for her estranged sister's well-being."}], 'role': 'model'}, 'finish_reason': 1, 'index': 0, 'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'token_count': 0, 'grounding_attributions': []}], 'prompt_feedback': {'safety_ratings': [{'category': 9, 'probability': 1, 'blocked': False}, {'category': 8, 'probability': 1, 'blocked': False}, {'category': 7, 'probability': 1, 'blocked': False}, {'category': 10, 'probability': 1, 'blocked': False}], 'block_reason': 0}}),
#  )]

# %%
# Function to generate rewrite prompts using the Gemini API
def generate_rewrite_prompts(aspect_area, count):
    prompts = []
    for i in range(count):
        aspect_name = aspect_area["name"]
        aspect_description = aspect_area["description"]

        #prompt = f"Suppose I have a input text, and I want my genAI model to rewrite this text in different way. Now please only generate a high quality rewrite prompt for my model for this task: {aspect_name}. As described here {aspect_description} The prompt should be creative, clear, specific, and consistent in format. For example, if your prompt involve in a certain Genre, be specific on genre, an don't be vague in the prompt. It should cover a diverse range of topics and styles. Avoid bias and ensure the prompt is generalizable. You will not be given the original text, so your prompt should be applicable to any input text. Dont leave any blank spaces or leave a [ ] that I will need to fill in later in the prompt. The prompt should be a full sentence. Limit the prompt to 30 words. Please do not include any special characters or symbols in the prompt."
        prompt = f"Take a deep breath before you get started. Please craft a unique sentence that instruct a student to rewrite any input text according to this task {aspect_description}. Your sentence must be imaginative, precise, and detailed, avoiding ambiguity and generalities. It should not only fit within a 30-word limit but also be versatile enough to apply to a wide variety of texts. Specify the genre or style directly when relevant, and ensure the sentence is clear and engaging without requiring further customization or the inclusion of brackets or placeholders. Create a standalone sentence that embodies all these criteria, making sure it's free from any special characters or symbols. Thanks!"

        response = model.generate_content(
            prompt,
            generation_config=genai.types.GenerationConfig(
                temperature=0.9)
        )

        generated_prompt = response.candidates[0].content.parts[0].text

        # Check if the generated prompt contains '[' or ']'
        special_chars = ['[', ']', '<', '>', '{', '}']
        if any(char in generated_prompt for char in special_chars):
            print("Special characters found in the generated prompt. Skipping...")
            continue 

        prompts.append(generated_prompt)
        print(generated_prompt)
        
        time.sleep(1)  # Add a delay to avoid hitting rate limits

    return prompts

# Generate rewrite prompts for each aspect/area
rewrite_prompts = []
# randomly select an aspect area and generate rewrite prompts, create a total of 500 prompts
for i in range(500):
    aspect_area = random.choice(aspects_areas)
    try:
        prompts = generate_rewrite_prompts(aspect_area, 2)
        time.sleep(1)
    except Exception as e:
        print(f"reach the limit of the API, stop here for 5 minutes")
        time.sleep(300)
        pass
    rewrite_prompts.extend(prompts)

# Print the total number of generated rewrite prompts
print(f"Total rewrite prompts generated: {len(rewrite_prompts)}")
# Out:
# Reimagine the text as an ancient tapestry woven by divine hands, interlacing mortal tales with the threads of mythical beings, epic quests, and legendary wonders.
# Reimagine your text as an epic tapestry woven with threads of ancient myth, where gods, heroes, and mythical beasts dance upon the stage of destiny.
# Take a deep breath and reshape the text to foster a healthier lifestyle by weaving in physical well-being guidance, mental resilience tips, or daily habit recommendations.
# Reimagine your text as a tapestry of vibrant wellness, weaving threads of physical vitality, mental clarity, and holistic nourishment into every fiber.
# Embark on a literary voyage, reweaving the tapestry of words to resonate with a diverse audience, where cultural echoes dance harmoniously with the original text's soul.
# Reimagine the text as a cultural tapestry, weaving threads of inclusivity and relevance to embrace a diverse audience's hearts and minds, honoring the original intent while illuminating new avenues of connection.
# Reimagine the text through the eyes of another, infusing it with their unique voice and viewpoint, while maintaining its essence.
# Don the mantle of a distinct persona, weaving a tapestry of words that mirrors their unique viewpoint, yet remains faithful to the tale's essence.
# Transform the provided text into a captivating dialogue, ensuring naturalism, coherence, and alignment with the characters' personas and interactions.
# Transform textual content into vibrant dialogue that captures the essence of characters, settings, and narrative style.
# Rephrase the provided text while infusing it with a distinct emotional undertone, like joy, sorrow, foreboding, or nostalgia, by carefully selecting words, adjusting sentence flow, and employing evocative imagery.
# Reimagine the text with a vivid emotional symphony, subtly weaving words, rhythm, and imagery to evoke the desired sentiment, without altering the message's essence.
# Morph the mundane into the mystical tapestry of mythology, weaving tales anew amidst celestial beings, ancient lore, and transformative epic journeys.
# Immerse yourself in ancient lore and mythical realms, recasting your words as tales spun by gods, where heroes soar, and legends echo through time.
# "Reimagine the text's tapestry, weaving in hues of local culture, vibrant examples, and resonant references to captivate your intended audience."
# Transform the given text into a vibrant tapestry of local hues and cultural threads, artfully tailoring vocabulary, examples, and tone to resonate deeply with the intended audience's heartstrings.
# Reimagine your text as an interactive tapestry where choices intertwine, shaping the narrative's destiny.
# Weave the text into an immersive tapestry of choices, where readers embark on a branching adventure filled with twists and turns that unfold with each decision they make.
# Embark on an educational odyssey by transforming any text into a comprehensive curriculum, brimming with objectives, lessons, captivating activities, and insightful assessments, tailored to ignite student engagement and cultivate a profound learning experience.
# Reimagine any text as an immersive learning journey with tailored objectives, captivating lessons, interactive activities, and comprehensive assessments, transforming it into an engaging educational masterpiece.
# Transform the given text into a succinct tapestry of its core, capturing the vital threads while unraveling the superfluous, for a swift understanding of the essence woven within.
# Condense the essence of a text like a skilled sculptor chiseling away excess, revealing its core meaning in a succinct and impactful summary.
# Visualize your text as a vibrant tapestry of multimedia expressions, weaving a storyboard that captivates eyes and hearts.
# Transform your words into a vibrant tapestry of scenes, soundscapes, and frames, weaving a multimedia masterpiece that captivates the senses.
# Reimagine the given text with a distinct emotional tapestry, weaving a consistent tone throughout that aligns with the desired sentiment, whether formal, friendly, assertive, or brimming with empathy.
# Retune the text's melody to resonate with the intended sentiment, ensuring its every note harmonizes with the desired emotional symphony.
# Morph the given text into an immersive experience where the reader navigates a branching narrative or dialogue, making choices that shape the story's path and lead to unique outcomes.
# Breathe deeply, then alchemize your text into an interactive realm where choices ripple through branching narratives, shaping destinies and unveiling unique outcomes.
# Embark on a sensory journey, enriching your descriptions with vivid hues, evocative sounds, tactile textures, tantalizing tastes, and intoxicating aromas.
# Reimagine your text with vibrant hues, evocative sounds, tactile textures, tantalizing flavors, and aromatic scents that leap off the page, immersing readers in a symphony of sensory experiences.
# Reimagine the given text through the multifaceted lens of a designated persona, retaining the essence while infusing it with the unique viewpoint and voice of your chosen perspective.
# Morph the text into a vibrant mosaic through the lens of a distinct observer, preserving its essence while infusing it with a fresh perspective.
# "Transform the text's technical tapestry: unravel jargon for clarity's sake, or weave in specialized threads to elevate its erudition."
# Rephrase this text using the language of (genre/style), ensuring clarity for (audience).
# Repurpose the text's essence, tailoring its words, syntax, and structure to embody the essence of a distinct writing style, preserving its core meaning.
# Metamorphose the written fabric into a new stylistic tapestry, preserving its essence while infusing it with the desired genre's colors, patterns, and textures.
# Imaginatively transform any text into an educational module, complete with objectives, lessons, activities, and assessments, tailoring it for learning environments and student engagement.
# Reimagine any text as an immersive educational journey, crafting objectives, lessons, activities, and assessments that captivate students and achieve learning goals.
# Reimagine the text with dialogue that flows effortlessly, capturing the essence of the characters and igniting the scene with realism and enchantment.
# Transform the provided text into a lively and believable exchange, reflecting the characters' personas and the context with seamless coherence and natural flow.
# Infuse your words with a kaleidoscope of sensory details, transforming dull descriptions into vibrant tapestries that ignite the reader's imagination and transport them into the heart of the narrative.
# Enliven narratives with vibrant sensory details, painting vivid scenes through sight, sound, touch, taste, and smell, immersing readers in an engaging tapestry of sensory experiences.
# Reimagine the given text as captivating dialogue, ensuring authenticity, coherence, and harmony among characters' attributes and dynamics.
# Reimagine the provided text as a compelling dialogue that breathes life into the context, ensuring it's natural, coherent, and aligned with the characters' personas and dynamics.
# Paint your words with the vibrant hues of the senses, capturing the sights, sounds, scents, textures, and tastes that ignite the imagination and immerse readers in a captivating tapestry.
# Enliven your text by weaving in sensory threads that paint vivid tapestries, immersing readers in a kaleidoscope of sights, sounds, touches, tastes, and scents.
# Reimagine the text as an epic tapestry woven by the Fates, where deities clash and mythical creatures roam, their actions shaping the narrative in a grand mythological spectacle.
# Reweave the tapestry of your text, intertwining threads of mythology and folklore, casting your sentences as ancient tales whispered by gods and mythical creatures.
# Embellish your prose with a kaleidoscope of sensory delights: sight's vibrant tapestry, sound's mellifluous symphony, touch's soft caress, taste's delectable dance, and the heady perfume of scent.
# Awaken your senses and paint a canvas of vivid imagery, transforming the mundane into a symphony of sights, sounds, tastes, textures, and scents that ignite the reader's imagination.
# Reimagine the text as a contemplative tapestry, interwoven with ethical quandaries, philosophical musings, and moral reflections that resonate within the depths of your consciousness.
# Reimagine the text as an ethical kaleidoscope, exploring moral quandaries and philosophical depths through nuanced scenarios, evocative dialogues, and contemplative reflections that challenge your perceptions and spark profound introspection.
# With artful imagination and meticulous touch, transmute the text as if through a sorcerer's spell, aligning its essence with the tapestry of a chosen genre.
# With a heart filled with imagination and a pen poised like a magic wand, transform your mundane text into a literary masterpiece, breathing life into its words through the prism of your chosen genre.
# Immerse yourself in the realm of knowledge by transforming diverse texts into captivating educational journeys, empowering students with objectives, lessons, activities, and assessments tailored to their learning aspirations.
# Craft an educational odyssey, transforming texts into interactive quests with defined goals, thematic voyages, immersive expeditions, and treasure chests of knowledge to unlock the wonders of learning!
# Transform text to make it more accessible or technically sophisticated, bridging the knowledge gap with linguistic alchemy, crafting either clarity or depth.
# Transform the text's linguistic landscape: simplify complex jargon or elevate it with specialized terminology to suit the intended audience.
# Reimagine the text's technicality by transforming it into either a jargon-free beacon of clarity or a jargon-infused bastion of specialized knowledge, catering to your intended audience's comprehension needs.
# Transmute text like a linguistic alchemist, distilling complexity for clarity or infusing simplicity with technical erudition.
# Reimagine the text with the eyes of a cultural chameleon, adorning it with familiar colors, rhythms, and nuances that embrace the new audience like a warm embrace.
# Reimagine the text as a vibrant tapestry woven with threads of diverse cultures, honoring its essence while inviting a new audience to connect through shared values and relatable references.
# Renovate your words like a master tailor, reshaping the fabric of text to dance with the rhythm of a specified genre.
# Metamorphose the text's visage to mirror the desired style's aesthetics, preserving its essence while imbuing it with the linguistic hues and structural tapestry of its new genre.
# Transform the text's linguistic landscape, either simplifying its terrain for broad comprehension or elevating its discourse with specialized vocabulary from diverse domains.
# Transmute the text's complexity, like an alchemist turning lead into gold, by either distilling jargon or enriching it with specialized knowledge, catering to diverse audiences.
# Reimagine your text as a sanctuary of health and well-being, weaving in expert advice and transformative insights to foster a vibrant, balanced lifestyle.
# Craft a transformative narrative that advocates holistic well-being by seamlessly weaving in practical guidance and insights on physical fitness, emotional equilibrium, and optimal lifestyle choices.
# Immerse readers in a vibrant tapestry of sensory experiences by capturing the sights, sounds, scents, textures, and tastes that ignite imagination and deepen understanding.
# Immerse your readers in a sensory symphony by painting vivid pictures through rich descriptions that tantalize the senses of sight, sound, touch, taste, and smell.
# Rephrase the provided text, preserving its essence yet employing distinct vocabulary and sentence constructions to render it comprehensible and succinct for a broader readership.
# Embrace the power of words as you reshape any text, breathing new life into its meaning while preserving its essence, making it shine with clarity, conciseness, and universal comprehension.
# Immerse yourself in the tapestry of words and reweave it to unravel the intricate threads of morality, ethics, and philosophy, exploring the depths of human dilemmas and illuminating the path to virtue.
# Reimagine the text as an ethical labyrinth, posing thought-provoking dilemmas and inviting readers on a philosophical odyssey to unravel the intricate tapestry of moral implications.
# Re-imagine the text as a captivating melody, harmonizing with the desired emotion, its notes flowing seamlessly to create a symphony of intended sentiment.
# Rephrase the text with the grace of a chameleon, adapting its tone to mirror the intended emotion, whether it be formal, friendly, assertive, empathetic, or any other, ensuring consistency throughout the metamorphosis.
# Transform the tale by weaving in the vibrant tapestry of a festival's traditions, capturing its essence through evocative descriptions of rituals, historical anecdotes, and cultural practices.
# Craft a rich narrative by interweaving the vibrant threads of cultural traditions, infusing the text with the spirit of a chosen festival, holiday, or celebration, honoring its rituals and significance.
# Transform convoluted prose into a limpid tapestry of simple words, succinct sentences, and crystal-clear elucidation, accessible to all who seek understanding.
# Transform complex prose into a lucid tapestry, weaving simpler words, shorter threads, and crystal-clear expositions to embrace a diverse audience.
# Compose engaging, natural dialogue that authentically reflects the nuances and dynamics of the characters and context provided.
# Transform the text into an authentic and enthralling dialogue, capturing the essence of the characters and their interactions within a cohesive and realistic narrative.
# Young scribes, transform words into a vibrant tapestry that dances on the page, tailoring your masterpiece to the age of your audience like a tailor trims a suit.
# Imagine your words transforming into a sparkling new tale! Rewrite the text as if it were a thrilling adventure, a heartfelt story, or even a cool rap song – make it so awesome, you'd want to share it with the whole world!
# Immerse yourself in the text, transforming it with sensory tapestry that paints vibrant scenes, evocative emotions, and palpable actions, weaving a spellbinding experience for the reader.
# Embolden your prose with sensory splendor, weaving a tapestry of sights, sounds, scents, tastes, and textures that ignite the reader's senses and immerse them in the story's vibrant world.
# Transmute text like an alchemist, distilling complexity or infusing with expertise, tailoring it to reach diverse minds.
# Embark on a linguistic odyssey, transforming technical text into accessible prose or elevating general text with expert jargon, shaping language to suit any audience's grasp.
# Assume a new persona, embodying their thoughts, experiences, and biases, to retell the narrative as seen through their unique lens, capturing the nuances and complexities of their viewpoint.
# Through the kaleidoscope of perception, rewrite the text, painting it afresh from the vibrant hues of a chosen viewpoint, preserving essence while embracing transformation.
# Immerse your readers in the tapestry of sensory details, painting vibrant hues of sight, echoing whispers of sound, caressing textures of touch, tantalizing tastes, and aromatic fragrances that ignite imagination and captivate the soul.
# Breathe deeply as you alchemize text into a sensory tapestry, evoking a vibrant dance of sights, sounds, textures, flavors, and scents that mesmerize the mind's eye and transport the reader to a realm of heightened immersion.
# Embark on a linguistic metamorphosis, transforming the tapestry of words into a lucid masterpiece, preserving the essence while donning a new literary attire.
# Reimagine the tapestry of words before you, weaving a new fabric with the essence preserved, a symphony of synonyms and restructured sentences that unfurls meaning with effortless clarity.
# Special characters found in the generated prompt. Skipping...
# Become a linguistic alchemist, transforming words into gold as you reshape a text's style to match a chosen genre, preserving its essence while infusing it with a dazzling new flair.
# Transform any text into its refined counterpart: normalize informal language, correct grammar, eliminate slang, and ensure adherence to standard conventions, preserving the essence while elevating the expression.
# Embrace linguistic metamorphosis by transforming the vernacular tapestry into a tapestry of formal prose, where abbreviations wilt, colloquialisms wither, and grammatical errors retreat.
# Embark on a literary metamorphosis, reshaping the tapestry of words to mirror the vibrant hues of your desired style, be it academic rigor, journalistic clarity, or creative brilliance.
# Metamorphose the text's essence through the prism of a specified genre, preserving its core while adorning it with the linguistic tapestry and structural symphony of the desired style.
# Transform the text into a captivating multimedia script or storyboard, orchestrating a visual symphony that mirrors the narrative's essence and resonates with the chosen format's strengths.
# Visualize your text as a captivating multimedia experience, transforming words into scenes, dialogue, and visual elements that ignite engagement and convey the original message with dynamic flair.
# Rephrase this text as if targeting a different audience: either simplify jargon-heavy language or elevate general text with technical concepts from fields like medicine, law, engineering, and more.
# Rephrase the provided text as if viewed through a kaleidoscope of technicality, either demystifying jargon for clarity or elevating simplicity with specialized terminology.
# Transform the text's tapestry into a vibrant panorama, adapting its threads to resonate with a diverse audience, bridging cultural chasms while preserving the masterpiece's essence.
# Metamorphose the words into a tapestry that whispers to the hearts of a distant land, weaving insights and experiences to bridge cultural divides while honoring the essence of the original narrative.
# Repurpose any text, crafting captivating dialogue that reflects character dynamics, context, and the essence of the genre, ensuring natural flow, coherence, and alignment with the narrative's core elements.
# Craft a realistic and compelling dialogue from the provided text, capturing the essence of each character and weaving a tapestry of engaging conversation.
# Elevate your text by transforming informal expressions into polished prose, preserving its essence while embracing formal language conventions.
# With meticulous care, illuminate the text's depths, transforming colloquial veils into a tapestry of formal elegance.
# reach the limit of the API, stop here for 5 minutes
# Imaginatively transform the text into a multifaceted multimedia script or storyboard, seamlessly weaving visual narratives, captivating audio, or sequential imagery to amplify its impact.
# Transform existing text into a captivating script or storyboard for multimedia formats, envisioning its visual and auditory elements to enhance the narrative.
# Reimagine the given text with a fresh perspective, preserving its essence while crafting a comprehensible tapestry of words, tailored to engage all minds.
# Reimagine the given text with a fresh perspective, recasting sentences and substituting words, while preserving the essence of the original meaning to make it readily comprehensible for a broader readership.
# Metamorphose the text into a literary labyrinth, weaving new tales within its threads as you transmute genres, adorning it with the hues and textures of diverse literary realms.
# Take a deep literary dive and reimagine any text as a genre-bending masterpiece, weaving the content into a tapestry of vivid imagination that echoes the conventions of your chosen realm.
# Transform the text into a captivating tale that dances to your imagination's rhythm, painting vivid colors fit for your special age group's eager eyes.
# Morph the text into your own words, like a magical shapeshifter, making it cool for your age group!
# Embark on a linguistic metamorphosis, transmuting your text into a tapestry woven with the threads of a specified style, preserving its essence while adorning it in the garb of a new genre.
# Reimagine the text's fabric, tailoring its language, sentence tapestry, and overall presentation to suit the vibrant hues of a specified genre or style, preserving its essence while infusing it with the unique charm of its new literary abode.
# Reimagine the text through the cosmic lens of science fiction or fantasy, weaving in elements of alien civilizations, cybernetic wonders, mystical realms, or dystopian societies to craft a tapestry of alternate realities.
# Reimagine the text as a captivating tapestry woven with threads of advanced tech, alien encounters, enchanting realms, or the chilling echoes of dystopian futures.
# Transform the provided text into its normalized form, ensuring adherence to standard language conventions and maintaining the integrity of its intended message.
# Transform your text into a tapestry of linguistic elegance, unraveling abbreviations, subduing slang, and replacing informality with the pristine threads of formality, all while preserving its essence.
# Reimagine the text as a vibrant tapestry, deftly weaving in cultural threads that resonate with your diverse audience, preserving the essence while adapting it to embrace the richness of their world.
# Reimagine the text's tapestry, weaving it with threads of cultural resonance to embrace a new audience's heart and mind.
# Transform your text into a vibrant tapestry by seamlessly weaving in elements of a chosen cultural festivity, reflecting its unique rituals, historical roots, and profound significance.
# Immerse your text in the vibrant tapestry of a chosen festival or celebration, capturing its traditions, rituals, and cultural essence through skillful adaptation.
# Wizards, warriors, or wordsmiths, transform this tale into a tapestry that weaves through the ages of your mind, making it fresh, vibrant, and worthy of a bard's song!
# Weave your words anew, like a young wizard crafting a magical tome, transforming any text into a thrilling yarn that dances with your imagination.
# Rephrase the text as a timeless tapestry, weaving together the threads of epochs past, adorning it with the vibrant hues and eloquent prose of bygone eras.
# Transcribe the text into the bygone era's lexicon, employing its idioms and cultural tapestry to weave a narrative that resonates with the spirit of the time.
# Reforge your words into an ethical tapestry, weaving in thought-provoking dilemmas, philosophical musings, and moral threads that challenge readers to plumb the depths of the human experience.
# Reimagine the text as a philosophical tapestry, weaving in ethical dilemmas, soul-searching questions, and profound reflections to unveil the hidden threads of morality beneath its surface.
# Transform your text into a sensory tapestry, weaving vivid descriptions that tantalize sight, sound, touch, taste, and smell, immersing readers in a world that comes alive.
# Immerse the reader in a sensorial tapestry by weaving vibrant descriptions that engage the senses, transforming ordinary words into a kaleidoscope of sights, sounds, scents, tastes, and tactile experiences.
# Immerse yourself in sensory wonders as you reweave the narrative tapestry, adding vibrant hues, evocative aromas, and tangible textures to paint scenes and emotions that captivate the reader's senses.
# Immerse yourself in the moment and weave a tapestry of sensations that awaken the senses, transforming every description into a vibrant symphony of sensory delights.
# Transform the text into a lucid tapestry, unraveling complex threads with simpler words, concise sentences, and illuminating explanations, making it accessible to all.
# Transform the text into a simplified masterpiece, making it accessible to all ears, like a symphony for every mind.
# Reimagine the text's essence, infusing it with the desired emotional tone, ensuring consistency and harmony throughout its entirety.
# Transform the text's voice, imbuing it with the desired emotion or attitude, ensuring seamless consistency throughout.
# Immerse yourself in the characters' world, breathing life into their words as you weave a tapestry of captivating and authentic dialogue that unfolds like a captivating tale.
# Immerse yourself in the text and conjure believable dialogue that mirrors the characters' essences, maintaining coherence, relatability, and genre-specific nuances.
# Reimagine your text as a captivating choose-your-own-adventure odyssey, where every page turn unfolds a world of branching narratives and user-driven destinies.
# Immerse yourself in a narrative labyrinth, where your choices shape the unfolding tale and lead you to diverse destinies.
# Reimagine the text with a satirical lens, humorously critiquing its elements while infusing it with your own creative zest to deliver a witty commentary.
# With a wry smile, transform the text into a satirical masterpiece, playfully skewering its content, characters, or themes with your wordsmithery.
# Don the mantle of another's viewpoint, weaving a tapestry of words that reflects their distinct perspective, preserving the narrative's soul and tapestry of meaning.
# Assume the lens of a distinct observer and reword the given text from their unique vantage point, capturing their beliefs, biases, and experiences while maintaining the text's essence.
# Rephrase the text as if explaining it to a curious, open-minded extraterrestrial visitor who has a basic grasp of English but limited cultural context.
# Transform text into a simplified tapestry of words, weaving clarity and understanding for all, bridging gaps of language and literacy.
# Reforge your text in the crucible of mythology, blending ancient lore into the narrative's tapestry, weaving tales where heroes clash, monsters lurk, and gods intervene.
# Embark on an epic odyssey, weaving the threads of mythology into the tapestry of your tale, transforming ordinary words into an extraordinary saga of gods and creatures from realms unknown.
# Immerse yourself in the transformative alchemy of text, recasting it as an educational masterpiece, complete with objectives, lessons, activities, and assessments, tailor-made for the crucible of learning.
# Eager wordsmiths, inhale wisdom, then exhale a curriculum that educates, entertains, and empowers, aligning knowledge with learning goals and students' hearts.
# Metamorphose the text's essence into a literary tapestry, tailoring its prose, tone, and motifs to the genre's unique enchantment.
# Imaginatively metamorphose the given text, infusing it with the genre's essence, aligning its content with genre conventions, and transforming its style and tone to match the genre's flair.
# Infuse the text with a healing elixir of health and wellness tips, transforming it into a treasure trove of practical advice on physical vitality, mental serenity, and lifestyle enhancements.
# Reimagine your text as a haven of health, weaving advice on fitness, serenity, and mindful living to craft a tapestry of well-being and vitality.
# Recast the given text into a simpler form, employing lucid vocabulary, succinct sentences, and crystal-clear explanations to enhance comprehension for a diverse audience.
# Reimagine the given text as a captivating tale spun in lucid prose, unfurling its meaning with simple elegance for every curious mind to unravel.
# Special characters found in the generated prompt. Skipping...
# Immerse the text in the vibrant tapestry of a chosen cultural event, seamlessly weaving in traditions, rituals, and historical significance to create a richer, more evocative narrative.
# Transform the narrative's tapestry by reweaving it in a novel voice or perspective, be it through the eyes of a detached observer, an active participant, or an unseen witness to the tale's unfolding.
# Weave the tapestry of words anew, altering the voice behind the tale, stepping into different shoes, and lending fresh eyes to the unfolding narrative.
# Morph the text into a contemplative labyrinth, weaving in ethical quandaries, philosophical musings, and moral crossroads that challenge readers to navigate their own paths of reflection.
# Embark on a literary journey where you weave ethical enigmas, philosophical ponderings, and moral teachings into the fabric of the text, inviting readers to delve into the depths of human nature and the complexities of right and wrong.
# Reimagine the text as a philosophical tapestry, weaving ethical threads and moral quandaries that invite introspection and ignite the flame of contemplation.
# Explore hidden depths by rephrasing the text, weaving in ethical complexities, thought-provoking questions, and moral reflections through engaging scenarios and dialogues.
# Metamorphose the text's narrative tapestry by shifting its voice or perspective, breathing new life into the tale with every transformed word.
# Transform the text's narrative tapestry by reweaving its threads from a novel vantage point, altering voice and perspective as you deem fit.
# Rephrase the text with simplified language, shorter sentences, and clearer explanations to make it accessible for all readers.
# Transform complex text into a lucid tapestry of words, woven with simplicity, brevity, and clarity, inviting comprehension for all.
# Embark on a literary metamorphosis, reshaping words into an emotive tapestry that aligns with the intended sentiment, a transformative journey from text to emotional resonance.
# Reimagine the text with the deft touch of a maestro, infusing it with the desired emotional resonance, maintaining consistency, and ensuring the message's harmony with the chosen tone.
# Like alchemists transmuting base metals into gold, transform the input text into standardized prose, preserving its essence while adhering to the conventions of formality.
# Transmute the given text into its formal counterpart, ensuring the normalized version mirrors the original's intent while embracing standard language, correct grammar, and impeccable punctuation.
# With a mind open to new possibilities, reweave the tapestry of words to create an eloquent and accessible rendition that unveils its essence anew.
# Transform the given prose into a lucid tapestry of words that weaves a fresh narrative, preserving the essence yet adorned with a distinct sartorial elegance.
# Transform the text into a vibrant tapestry of new words, keeping the essence alive while tailoring it for a wider tapestry of understanding.
# Transform the given text into a fresh tapestry of words, preserving its essence while unveiling clarity and accessibility for all.
# Unleash your inner bard and reforge the narrative tapestry, weaving threads of myth and legend into your text, transforming it into an epic odyssey of gods, heroes, and ancient lore.
# Reimagine the mundane as an epic saga, weaving in deities, mythical beings, and the echoes of ancient lore.
# Immerse yourself in a holistic editing endeavor, reimagining the text as a tapestry of health and wellness, weaving in threads of physical vitality, mental resilience, and lifestyle enhancements to cultivate a vibrant and harmonious existence.
# Craft a rejuvenating tapestry of words that promotes a healthier lifestyle, infusing existing text with practical advice on physical and mental well-being.
# Reimagine the fabric of words, weaving them anew into a tapestry of desired prose, preserving essence while adorning it in the garb of the targeted style.
# Metamorphose the text's form, donning a new stylistic guise while preserving its essence, like a chameleon adapting to its surroundings.
# Compose dialogue that feels alive, fitting the characters, situation, and genre, ensuring natural flow, coherence, and consistency throughout the conversation.
# Craft a realistic and engaging dialogue that's natural, coherent, and true to characters, considering the genre, style, and context provided.
# Transform any given text into its proper and conventional form, maintaining its essence while adhering to formal language, correct grammar, and standard punctuation.
# "Metamorphose text into its formal finery, transforming jargon and informality into an elegant tapestry of standardized language, adhering to the etiquette of proper grammar, spelling, and punctuation, while preserving its original intent."
# Immerse yourself in the depths of sensory perception, painting each word with vibrant hues of sight, sound, touch, taste, and scent, transforming the narrative into a captivating tapestry for the reader's senses.
# Dip your quill in the vibrant hues of sensory details, painting vivid landscapes that tantalize the senses and captivate the imagination.
# Imaginatively transform the given text into a genre or style of your choice, creatively reworking the content to adhere to its conventions.
# Step into a literary realm and transform your words, crafting a genre-bending tapestry where tales unfold anew.
# Transform your text into a captivating interactive experience, branching into multiple paths and outcomes guided by user choices, be it a choose-your-own-adventure tale, an immersive tutorial, or a gripping role-playing game script.
# Morph the text into an immersive tapestry of choices, where paths diverge based on the reader's whims, weaving a dynamic narrative rich with interactive twists and turns.
# Reimagine the text with the melodies of your heart, weaving hues of emotion into its tapestry, preserving its essence while awakening the echoes of joy, sorrow, anticipation, or reverie within the reader's soul.
# Immerse yourself in the symphony of words, then rewrite the text as a melody that resonates with the chosen emotion, ensuring the essence remains intact, yet adorned with subtle nuances to awaken the desired feelings in the reader's heart.
# Reimagine the provided text as a tale woven in the tapestry of distant galaxies, enchanted realms, or worlds of dystopian futures, where advanced technology, mythical creatures, and ethereal powers intertwine in a grand spectacle of creativity.
# Morph the text into a fantastical tapestry, weaving elements of advanced technology, alien civilizations, magical realms, or dystopian futures to create an alternate universe brimming with both wonder and peril.
# Compose realistic, engaging dialogue from the provided text, ensuring natural cohesion, consistency, and alignment with character attributes and dynamics.
# Transform the given text into a captivating dialogue, ensuring natural flow, authentic character voices, and a captivating ambiance reflective of the specified genre or context.
# Infuse your rewritten text with the vibrant tapestry of a cultural celebration, capturing its traditions, rituals, and profound significance.
# Special characters found in the generated prompt. Skipping...
# With imagination as your quill, transcribe the mundane into the realm of genres, reworking each line to align with the chosen style's unique shine.
# With innovative fervor, transform the mundane into the extraordinary, weaving the essence of your chosen genre into every thread of the rewritten tapestry.
# Inhale deeply and transmute your text into a sanctuary of health and wellness, nurturing both body and mind with insights that empower a vibrant and harmonious existence.
# Transform the given text into a tapestry of health and wellness, weaving in threads of physical vitality, mental serenity, and lifestyle alchemy to craft a healthier, more balanced masterpiece.
# Craft a fantastical or futuristic retelling by integrating advanced technology, mystical realms, or extraterrestrial civilizations to explore alternate realities.
# Reimagine this text as a vibrant tapestry woven with threads of advanced technology, ethereal landscapes, or the haunting echoes of dystopian futures.
# Don your literary cloak and reimagine the narrative from a novel character's lens, capturing their distinct voice, beliefs, and motivations.
# From the depths of a distinct prism, reimagine the narrative, weaving it with the vibrant threads of a novel vantage.
# Craft a narrative from a distinct lens, weaving words that capture the essence of a new perspective while upholding the core message.
# Special characters found in the generated prompt. Skipping...
# Retread the tapestry of words, weaving them anew in the vibrant hues of a bygone era, its cadence echoing the whispers of time.
# Quill in hand, immerse thyself in the lexicon of yore, and transcribe the text as if penned in a bygone epoch, with words and turns of phrase that echo the spirit of the age.
# Craft a concise yet informative summary that distills the essence of the provided text, retaining crucial details while excising nonessential elements, allowing quick understanding.
# Before diving into the abyss of text, take a deep breath and let your pen dance gracefully, condensing words into succinct prose that captures the essence like a skilled sculptor chiseling away at marble, leaving behind only the masterpiece of clarity and brevity.
# Craft dialogue that's vivid and true, imbued with depth, reflecting characters' essence.
# Craft engaging, believable dialogue by transforming input into natural, authentic conversations that align with characters and contexts.
# Rewrite the given text in the style of your choice (e.g., academic, journalistic, creative), maintaining its essence while adapting language, structure, and presentation to the desired genre or style.
# Reimagine the text's tapestry, weaving it anew into a vibrant masterpiece that echoes with the symphony of your chosen style.
# Visualize the text's essence through multimedia's lens, crafting a script or storyboard that captivates through sight and sound.
# Imaginatively reimagine the text as a captivating script or storyboard, leveraging multimedia's strengths to amplify its impact.
# Reimagine the given text with a fresh perspective, crafting a new tapestry of words that retains its essence while illuminating its clarity and accessibility for all.
# Imagine the written words transforming before your eyes like a kaleidoscope of meaning, weaving a new tapestry of comprehension that unravels the complexities of the original text.
# Embark on a stylistic metamorphosis, morphing the text's visage into a desired genre's embrace, preserving its essence while cloaking it in a new linguistic tapestry.
# Forge the text's essence anew, donning it with the cloak of a desired style, be it academic's rigor, journalism's immediacy, or creativity's boundless dreams.
# Replicate the given text in a transformative dance of words, embracing a style that waltzes with grace, whispers with eloquence, or paints with vivid hues, while preserving its essence like a cherished memory.
# Sculpt the text's essence into a new literary masterpiece, echoing the target style's melody while preserving its core message.
# Transform the text's persona by infusing it with the desired tone, mirroring the nuances of formality, friendliness, assertiveness, or empathy, ensuring consistency and alignment with the text's intent.
# "Embark on a literary metamorphosis, transforming the text's essence with the brushstrokes of a chosen tone, ensuring consistent harmony between the message's intent and the language's symphony."
# Transform the text into a vibrant tapestry by infusing it with sensory details that evoke sight, sound, touch, taste, and smell, immersing readers in the scene's tangible reality.
# Infuse your writing with a symphony of senses, painting vivid canvases that awaken the reader's imagination, engage their emotions, and transport them into the heart of the narrative.
# Immerse yourself in the senses, painting a vibrant tapestry of words to evoke the sights, sounds, scents, tastes, and textures that ignite the reader's imagination.
# Immerse yourself in the senses, breathing life into words by weaving a tapestry of vibrant imagery that ignites the reader's imagination.
# Breathe deeply and reimagine any text as an immersive educational odyssey, complete with objectives, lessons, engaging activities, and tailored assessments that spark knowledge and empower learners.
# Embark on a literary transformation by recasting any text into an immersive educational module, meticulously crafting objectives, lessons, activities, and assessments that ignite student engagement and align with learning goals.
# Reimagine the text's persona by tailoring its language, cadence, and structure to embody a distinct writing style that captivates the intended audience.
# Navigate the stylistic sea with ease, transforming text into a new realm of language, structure, and form, while preserving its essence like a beacon in the night.
# Weave sensory tapestry into your writing, immersing readers in a vibrant realm where vivid hues dance, melodies whisper, textures caress, flavors tantalize, and scents enchant.
# Breathe in the essence of the task, then rewrite with vibrant hues, textures, and rhythms to captivate the senses and ignite the imagination.
# Craft a philosophical tapestry by weaving ethical dilemmas, philosophical inquiries, and moral quandaries into the fabric of the text, prompting readers to unravel the intricate threads of meaning embedded within.
# Reimagine the given text, infusing it with ethical dilemmas, philosophical quandaries, or moral lessons through imaginative scenarios, thought-provoking dialogues, and reflective prompts that encourage introspection on profound meanings and moral repercussions.
# Craft a fresh version of the given text, echoing its intent with distinct words and sentence structures, ensuring clarity, simplicity, and accessibility for diverse readers.
# Reimagine the text in a new tapestry of words, preserving the essence while weaving a fresh narrative for clarity and universal comprehension.
# Imaginatively rewrite the given text as realistic and engaging dialogue that aligns with the characters and context, ensuring natural flow and coherence.
# Transform any text into captivating dialogue that mirrors the characters' essence, flows seamlessly, and reflects their relationships and the narrative's ambiance.
# Transfigure the text into a labyrinth of ethics, philosophy, and morality, inviting readers to navigate dilemmas, ponder questions, and glean lessons through imagined scenarios, dialogues, and introspective reflections.
# Immerse yourself in the text's depths, excavating ethical conundrums, philosophical musings, and moral epiphanies through creative scenarios, enlightening dialogues, and introspective reflections.
# Breathe in vitality, exhale renewal: Reimagine your text as a sanctuary for health and wellness, infusing it with insights to uplift your well-being.
# Transform the text into a wholesome sanctuary of health and wellness, nurturing your physical vigor, emotional resilience, and mindful living.
# Transcend the mundane by reimagining your text as an enchanting odyssey through literature's diverse realms, weaving its essence into a tapestry of words that dances to a new rhythm.
# Morph the input text into a literary canvas of your choosing, mirroring the essence and conventions of that genre, while breathing new life into its content and form.
# Morph the text's technicality: from jargon-laced to plain-spoken or vice versa, like a linguistic alchemist transmuting knowledge.
# Embark on a linguistic metamorphosis, transforming texts by either shedding technical jargon or embracing it, making them accessible to diverse audiences.
# Reimagine the essence of the text with a distinct stylistic flair, preserving its core meaning while orchestrating a metamorphosis of its language, structure, and presentation to align with the desired genre's symphony.
# Reimagine the given prose with the finesse of a seasoned scribe, molding its essence into a new literary form that dances with the cadence of your target style.
# Rewrite the provided text from an alternative lens, embodying a unique vantage point or identity while maintaining its essence and coherence.
# Through the lens of your chosen perspective, reimagine the given text, capturing its essence from a unique vantage point while maintaining its core message.
# Rewrite the text from an ethical kaleidoscope, inviting readers to delve into a labyrinth of dilemmas, ponder philosophical musings, and unravel the moral threads woven throughout.
# Reimagine the text as a philosophical tapestry, weaving ethical dilemmas, moral paradoxes, and the introspection of human nature into its fabric, inviting readers to contemplate the intricate threads of existence.
# Evoke the essence of the text within your pen's embrace, painting an elaborate tapestry with vivid hues of detail, exemplifying the untold depths that lie beneath its surface.
# Embark on a literary journey, transforming text into a tapestry of depth and insight, weaving intricate threads of detail, exemplar, and lore, expanding horizons and enlightening minds.
# Immerse your readers by weaving a tapestry of sensory details that ignite the senses, revealing the world not merely through words but through a symphony of sights, sounds, scents, tastes, and textures.
# Immerse yourself in the senses, crafting a vivid tapestry from any text by infusing it with the symphony of sight, touch, sound, smell, and taste.
# Transfigure the text you behold into a tapestry woven with the threads of bygone eras, adopting the tongue, turns of phrase, and allusions that did grace those hallowed halls of time.
# Retranscribe yonder text into an era's tongue, weaving words and phrases as the folk of that time would.
# Transform the text into a lucid tapestry of words, preserving its essence while adorning it with fresh linguistic hues, ensuring clarity for all.
# Transform the provided text into a lucid tapestry of words, preserving its essence while weaving new expressions and structures for enhanced comprehension and accessibility.
# Transform the text into a satirical tapestry that weaves humor and critique, gently mocking the original while offering a playful commentary.
# With a sly grin, satirize the text by playfully skewering its characters, themes, or style, offering a humorous critique while inviting laughter and reflection.
# Young wordsmiths, transform this text into a vibrant tapestry that speaks to your youthful spirits, using your slang and the lingo that sets your hearts aflame!
# Time to transform the text, young wordsmith! Make it sizzle like your favorite song, flow like the coolest dance moves, or wise like a wise owl – tailor it to your age groove!
# Imbue the canvas of words with a palette of emotive hues, transforming text into a masterpiece of resonance.
# Rephrase the given text's words and phrases like you're a skilled thespian embodying the desired emotion, ensuring a seamless flow of the aligned message throughout.
# Composeth anew the text with tongue and pen of bygone days, adorning it with the raiment and parlance of yore.
# Transform the tapestry of words, weaving anew in the vibrant hues of a bygone era's tongue, syntax, and the cultural fabric that adorned it.
# Transform the informal tapestry of words into a formal parchment of pristine eloquence, preserving the essence while adorning it with the regalia of standardized language.
# Metamorphosis your text into formal elegance, shedding abbreviations and slang for a pristine tapestry of linguistic propriety.
# Retype the given text with a satirical flair, mocking its elements with wit and humor, balancing critique with creativity for a comedically critical take.
# With a whimsical quill dipped in irony, rewrite the text as a satirical masterpiece that jests at its core, unraveling its essence with a dash of wit and a wink.
# Reimagine the text's fabric by weaving in threads of local culture, tailoring it to resonate with the target audience's unique tapestry of experiences and perspectives.
# Reimagine the essence of the text, tailoring its contours to dance with the rhythms of the target audience's culture, dialect, and worldview.
# Reimagine the given text as a vibrant mosaic, intricately embellishing it with threads of detail, examples, and context that illuminate its depth and breadth.
# Unfold the textual tapestry with vibrant hues, weaving in intricate threads of detail, illuminating the fabric of understanding, and leaving an imprint of clarity upon the reader's mind.
# Rephrase the given text into a form that is more accessible by using varied wording and sentence constructions while preserving the original meaning.
# Craft a fresh tapestry of words, capturing the essence of the original text with distinct hues and patterns, weaving a comprehensible masterpiece for all to appreciate.
# Reimagine the text as a thought-provoking tapestry, weaving in ethical dilemmas, philosophical queries, and moral reflections that unravel the complexities of human nature.
# Reimagine the text as a thought-provoking tapestry, weaving in ethical quandaries, philosophical inquiries, and moral threads to unravel the profound truths that lie between the lines.
# Transmute the prose into a fantastical tapestry, weaving advanced technology, otherworldly civilizations, enchanted domains, or bleak futures into its fabric to envision the boundless possibilities of alternate realities.
# Reimagine the given text as a vibrant tapestry woven with the threads of science fiction or fantasy, where advanced technology, alien civilizations, enchanted realms, or dystopian futures ignite your imagination.
# Reimagine the given text's tapestry with the vibrant hues of a designated emotion, maintaining consistency and aligning with the message's intent.
# Immerse yourself in the text, infusing it with a newly imagined tone – be it warmth, authority, concern, or mirth – ensuring it resonates throughout, like a melody woven into a symphony.
# Reimagine the given text as a lucid tapestry of words, preserving its essence in a freshly woven pattern that illuminates understanding for all.
# Craft a reinvented narrative from the provided text, preserving its essence while employing fresh verbiage and sentence constructions to enhance clarity, brevity, and accessibility for a diverse readership.
# Transmit the essence of a text across cultural divides, infusing it with linguistic nuances, familiar references, and an empathetic tone that resonates with the target audience's shared experiences.
# Reimagine the text's tapestry, weaving in vibrant threads from diverse cultures, locales, and perspectives.
# Reweave the text's tapestry with threads of your chosen sentiment, ensuring its tonal hue remains consistent throughout.

# %%
# Save the rewrite prompts to a csv file wiht first column as id and second column as prompt
with open('/workspace/ligo_general/rewrite_prompts.csv', 'w') as f:
    f.write("id,rewrite_prompt\n")
    for i, prompt in enumerate(rewrite_prompts):
        # write the prompt to the with auto increment id
        f.write(f"{i+1},\"{prompt}\"\n")
